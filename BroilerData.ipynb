# %% [markdown]
# <a href="https://colab.research.google.com/github/mowens24/nfl_bets/blob/main/BroilerData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Upload files
uploaded = files.upload()

# List uploaded files
for filename in uploaded.keys():
    print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
# Out:
#      <input type="file" id="files-46dccbd7-970b-482e-82b9-f3473394df3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46dccbd7-970b-482e-82b9-f3473394df3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace 'your_file.xml' with your actual XML filename
xml_filename = 'report.xml'

# Attempt to read the XML file using pandas
try:
    df_xml = pd.read_xml(xml_filename)
    print("XML file read successfully.")
    display(df_xml.head())
except Exception as e:
    print(f"Error reading XML file: {e}")
# Out:
# XML file read successfully.
#    reportDate regionName          type  \
# 0  09/02/2022  SOUTHEAST  CONVENTIONAL
# 1  09/02/2022  SOUTHEAST     SPECIALTY
# 2  09/02/2022  SOUTHEAST       ORGANIC
# 3  09/02/2022  SOUTHEAST  CONVENTIONAL
# 4  09/02/2022  SOUTHEAST  CONVENTIONAL
#
#                                     description numStores  weightAvg  \
# 0       BREAST, BONELESS/SKINLESS, REGULAR PACK     1,143       3.99
# 1  BREAST, BONELESS/SKINLESS, SPECIALTY/ORGANIC       659       5.23
# 2  BREAST, BONELESS/SKINLESS, SPECIALTY/ORGANIC       436       7.49
# 3         BREAST, BONELESS/SKINLESS, VALUE PACK       406       3.07
# 4           BREAST, SPLIT BONE-IN, REGULAR PACK        50       2.89
#
#    lowPrice  highPrice  storeLowPrice  storeHighPrice  procLowPrice  \
# 0       NaN        NaN           3.99            3.99           NaN
# 1      3.48       5.99            NaN             NaN           NaN
# 2      5.99       8.99            NaN             NaN           NaN
# ...

# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()

# %%
df_xml
# Out:
#       reportDate regionName          type  \
# 0     09/02/2022  SOUTHEAST  CONVENTIONAL
# 1     09/02/2022  SOUTHEAST     SPECIALTY
# 2     09/02/2022  SOUTHEAST       ORGANIC
# 3     09/02/2022  SOUTHEAST  CONVENTIONAL
# 4     09/02/2022  SOUTHEAST  CONVENTIONAL
# ...          ...        ...           ...
# 4041  07/26/2024  SOUTHEAST     SPECIALTY
# 4042  07/26/2024  SOUTHEAST  CONVENTIONAL
# 4043  07/26/2024  SOUTHEAST  CONVENTIONAL
# 4044  07/26/2024  SOUTHEAST     SPECIALTY
# 4045  07/26/2024  SOUTHEAST  CONVENTIONAL
#
#                                        description numStores  weightAvg  \
# 0          BREAST, BONELESS/SKINLESS, REGULAR PACK     1,143       3.99
# 1     BREAST, BONELESS/SKINLESS, SPECIALTY/ORGANIC       659       5.23
# 2     BREAST, BONELESS/SKINLESS, SPECIALTY/ORGANIC       436       7.49
# 3            BREAST, BONELESS/SKINLESS, VALUE PACK       406       3.07
# 4              BREAST, SPLIT BONE-IN, REGULAR PACK        50       2.89
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_xml)
# Out:
# https://docs.google.com/spreadsheets/d/17ryR6-0HNkivO6gOPMP5XjCghNU8iwz4-y9K_ZWR87I#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/17ryR6-0HNkivO6gOPMP5XjCghNU8iwz4-y9K_ZWR87I#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
broiler_data
# Out:
#       reportDate regionName       type  \
# 0     01/05/2024  SOUTHEAST  SPECIALTY
# 1     01/05/2024  SOUTHEAST  SPECIALTY
# 2     01/05/2024  SOUTHEAST  SPECIALTY
# 3     01/05/2024  SOUTHEAST  SPECIALTY
# 4     01/05/2024  SOUTHEAST  SPECIALTY
# ...          ...        ...        ...
# 1115  12/22/2023  SOUTHEAST    ORGANIC
# 1116  12/22/2023  SOUTHEAST    ORGANIC
# 1117  12/29/2023  SOUTHEAST    ORGANIC
# 1118  12/29/2023  SOUTHEAST    ORGANIC
# 1119  12/29/2023  SOUTHEAST    ORGANIC
#
#                                        description numStores  weightAvg  \
# 0     THIGHS, BONELESS/SKINLESS, SPECIALTY/ORGANIC        67       3.98
# 1                        THIGHS, SPECIALTY/ORGANIC        34       1.49
# 2                               WHOLE BAGGED FRYER        10       1.98
# 3                BREAST TENDERS, SPECIALTY/ORGANIC       131       4.89
# 4     BREAST, BONELESS/SKINLESS, SPECIALTY/ORGANIC     1,097       4.93
# ...

# %%
# Import the necessary library for saving the dataframe to a pickle file
import pickle

# Define the path where you want to save the pickle file
# Include the file name in the path
file_path = '/content/drive/MyDrive/OWENS_FARM/df_xml_cleaned.pkl'  # Added file name

# Save the dataframe to a pickle file
with open(file_path, 'wb') as f:
    pickle.dump(df_xml_cleaned, f)

# Note: Make sure the 'OWENS_FARM' directory exists in your Google Drive

# %%
# prompt: can we now export the df_xml_cleaned data to an excel file to this path '/content/drive/MyDrive/OWENS_FARM'

# Assuming df_xml_cleaned is the DataFrame you want to export
df_xml_cleaned.to_excel('/content/drive/MyDrive/OWENS_FARM/df_xml_cleaned.xlsx', index=False)
